# %% [markdown]
# ## Data Loading

# %%
import pandas as pd

# %%
product=pd.read_excel("Behold+product+data+04262021.xlsx")

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61355 entries, 0 to 61354
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           61355 non-null  object
#  1   brand                61355 non-null  object
#  2   brand_category       60896 non-null  object
#  3   name                 61354 non-null  object
#  4   details              9200 non-null   object
#  5   created_at           61355 non-null  object
#  6   brand_canonical_url  61355 non-null  object
#  7   description          51238 non-null  object
#  8   brand_description    51234 non-null  object
#  9   brand_name           61354 non-null  object
#  10  product_active       61355 non-null  bool
# dtypes: bool(1), object(10)
# memory usage: 4.7+ MB

# %%
product.head()
# Out:
#                    product_id           brand brand_category  \
# 0  01EX0PN4J9WRNZH5F93YEX6QAF             Two        Unknown
# 1  01F0C4SKZV6YXS3265JMC39NXW  Collina Strada        Unknown
# 2  01EY4Y1BW8VZW51BWG5VZY82XW         Cariuma        Unknown
# 3  01EY50E27A0P5V6KCW01XPDB43         Cariuma        Unknown
# 4  01EY6DWHC2W5HPNEGXKEJ4A1CX         Cariuma        Unknown
#
#                                                 name details  \
# 0             Khadi Stripe Shirt-our signature shirt     NaN
# 1      RUFFLE MARKET DRESS LOOPY PINK SISTINE TOMATO     NaN
# 2             IBI Slip On Raw Red Knit Sneaker Women     NaN
# 3               IBI Slip On Black Knit Sneaker Women     NaN
# 4  CATIBA PRO Skate Black Suede and Canvas Contra...     NaN
#
#                     created_at  \
# 0  2021-01-27 01:17:19.305 UTC
# 1  2021-03-09 18:43:10.457 UTC
# 2  2021-02-10 02:58:59.591 UTC
# 3  2021-02-10 03:40:52.842 UTC
# 4  2021-02-10 16:55:13.024 UTC
#
#                                  brand_canonical_url  \
# 0  https://two-nyc.myshopify.com/products/white-k...
# 1  https://collina-strada-2.myshopify.com/product...
# 2  https://cariuma.myshopify.com/products/ibi-sli...
# 3  https://cariuma.myshopify.com/products/ibi-sli...
# 4  https://cariuma.myshopify.com/products/catiba-...
#
#                                          description  \
# 0  Our signature khadi shirt\navailable in black ...
# 1  Mid-length dress with ruffles and adjustable s...
# 2             IBI Slip On Raw Red Knit Sneaker Women
# 3               IBI Slip On Black Knit Sneaker Women
# 4                                                NaN
#
#                                    brand_description  \
# 0  Our signature khadi shirt\n\navailable in blac...
# 1  Mid-length dress with ruffles and adjustable s...
# 2             IBI Slip On Raw Red Knit Sneaker Women
# 3               IBI Slip On Black Knit Sneaker Women
# 4                                                NaN
#
#                                           brand_name  product_active
# 0             Khadi Stripe Shirt-our signature shirt            True
# 1      RUFFLE MARKET DRESS LOOPY PINK SISTINE TOMATO            True
# 2             IBI Slip On Raw Red Knit Sneaker Women           False
# 3               IBI Slip On Black Knit Sneaker Women           False
# 4  CATIBA PRO Skate Black Suede and Canvas Contra...           False

# %%
tags=pd.read_csv('usc_additional_tags USC.csv')

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97420 entries, 0 to 97419
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        97420 non-null  object
#  1   product_color_id  97420 non-null  object
#  2   attribute_name    97420 non-null  object
#  3   attribute_value   97420 non-null  object
# dtypes: object(4)
# memory usage: 3.0+ MB

# %%
tags.head()
# Out:
#                    product_id            product_color_id    attribute_name  \
# 0  01E5ZXP5H0BTEZT9QD2HRZJ47A  01E5ZXP5JCREDC7WJVMWHK5Q40  materialclothing
# 1  01E5ZXP5H0BTEZT9QD2HRZJ47A  01E5ZXP5JCREDC7WJVMWHK5Q40  materialclothing
# 2  01E5ZXP5H0BTEZT9QD2HRZJ47A  01E5ZXP5JCREDC7WJVMWHK5Q40             style
# 3  01E5ZXP5H0BTEZT9QD2HRZJ47A  01E5ZXP5JCREDC7WJVMWHK5Q40             style
# 4  01E5ZXP5H0BTEZT9QD2HRZJ47A  01E5ZXP5JCREDC7WJVMWHK5Q40             style
#
#   attribute_value
# 0      linenblend
# 1     cottonblend
# 2          modern
# 3  businesscasual
# 4         classic

# %% [markdown]
# ## Data Preprocessing

# %%
# Drop duplicates if applies

product.drop_duplicates(subset='product_id',keep='first',inplace=True)

# %%
# Remove irrelevant fields
cleaned_data=product.drop(['product_id','created_at','brand_canonical_url'],axis=1)

# %%
# Fill NaN values with "unknown"

cleaned_data = cleaned_data.fillna("unknown")

# %%
# Convert all the text values into lowercase and remove puctuations
import re

def clean(data):
    data=data.lower()
    data=re.sub(r'[^\w\s]','',data)
    return data

cols = cleaned_data.columns.values
for i in cols:
    if i=='brand':
        continue
    else:
        cleaned_data[i]=cleaned_data[i].astype(str).apply(clean)
# for i in cols:
#     if i=='product_active':
#         continue
#     else:
#         cleaned_data[i]=cleaned_data[i].astype(str).apply(lower)

# %%
# Perform lemmatization

import nltk
from nltk.stem import WordNetLemmatizer

def lemm(data):

    lemmatizer = WordNetLemmatizer()
    sentences = []
    
    for i in data:
        tokens = nltk.word_tokenize(i)
        words = []
        for word in tokens:
            words.append(lemmatizer.lemmatize(word))
        sentence = " ".join(words)
        sentences.append(sentence)
    return sentences

for i in cols:
    if i=='brand':
        continue
    else:
        cleaned_data[i]=lemm(cleaned_data[i])

# %%
# Get top 30 brands and classify the other brands as 'Others'

top_30_label = cleaned_data.groupby('brand')['brand'].count().sort_values(ascending=False).head(30).index.values

for i in range(len(cleaned_data)):
    if cleaned_data.iloc[i,0] in top_30_label:
        continue
    else:
        cleaned_data.iloc[i,0]='Others'

# %%
cleaned_data
# Out:
#                 brand        brand_category  \
# 0              Others               unknown
# 1      Collina Strada               unknown
# 2              Others               unknown
# 3              Others               unknown
# 4              Others               unknown
# ...               ...                   ...
# 61350          Others          sandalssales
# 61351          Others  flat sandalsarchives
# 61352          Others  flat sandalsarchives
# 61353          Others          sandalssales
# 61354          Others  flat sandalsarchives
#
#                                                     name  \
# 0                  khadi stripe shirtour signature shirt
# 1          ruffle market dress loopy pink sistine tomato
# 2                 ibi slip on raw red knit sneaker woman
# 3                   ibi slip on black knit sneaker woman
# 4      catiba pro skate black suede and canvas contra...
# ...                                                  ...
# 61350                bowvida mule in black suede kidskin
# 61351       sandale vida mule in tangerine suede kidskin
# 61352              bowvida mule in fuschia suede kidskin
# 61353              vida mule in silver metalized leather
# 61354           bowvida mule in bronze metalized leather
#
#                                                  details  \
# 0                                                unknown
# 1                                                unknown
# 2                                                unknown
# 3                                                unknown
# 4                                                unknown
# ...                                                  ...
# 61350  feminine flat mule square shape v line on the ...
# 61351  feminine flat mule square shape v line on the ...
# 61352  feminine flat mule square shape v line on the ...
# 61353  feminine flat mule square shape v line on the ...
# 61354  feminine flat mule square shape v line on the ...
#
#                                              description  \
# 0      our signature khadi shirt available in black a...
# 1      midlength dress with ruffle and adjustable str...
# 2                 ibi slip on raw red knit sneaker woman
# 3                   ibi slip on black knit sneaker woman
# 4                                                unknown
# ...                                                  ...
# 61350  the flat bowvida mule in black suede is the id...
# 61351  the flat vida mule in tangerine suede is the c...
# 61352  the flat bowvida mule in fuschia suede is the ...
# 61353  the flat vida mule in silver metalized leather...
# 61354  the flat bowvida mule in bronze leather is the...
#
#                                        brand_description  \
# 0      our signature khadi shirt available in black a...
# 1      midlength dress with ruffle and adjustable str...
# 2                 ibi slip on raw red knit sneaker woman
# 3                   ibi slip on black knit sneaker woman
# 4                                                unknown
# ...                                                  ...
# 61350  the flat bowvida mule in black suede is the id...
# 61351  the flat vida mule in tangerine suede is the c...
# 61352  the flat bowvida mule in fuschia suede is the ...
# 61353  the flat vida mule in silver metalized leather...
# 61354  the flat bowvida mule in bronze leather is the...
#
#                                               brand_name product_active
# 0                  khadi stripe shirtour signature shirt           true
# 1          ruffle market dress loopy pink sistine tomato           true
# 2                 ibi slip on raw red knit sneaker woman          false
# 3                   ibi slip on black knit sneaker woman          false
# 4      catiba pro skate black suede and canvas contra...          false
# ...                                                  ...            ...
# 61350                bowvida mule in black suede kidskin          false
# 61351       sandale vida mule in tangerine suede kidskin          false
# 61352              bowvida mule in fuschia suede kidskin          false
# 61353              vida mule in silver metalized leather          false
# 61354           bowvida mule in bronze metalized leather          false
#
# [61355 rows x 8 columns]

# %%
# Look at the distribution of brands among all the observations

cleaned_data.groupby('brand')['brand'].count().sort_values(ascending=False)/61355*100
# Out:
# brand
# Others                   25.407872
# 7 For All Mankind        14.686660
# Rails                     4.667916
# Intentionally Blank       4.130063
# A.L.C.                    3.409665
# Rachel Comey              3.391737
# Misa                      3.308614
# Studio 189                3.188004
# ASTR the Label            3.165186
# lemlem                    2.967973
# Simon Miller              2.364925
# Cynthia Rowley            2.195420
# Outerknown                2.180751
# Chufy                     1.970500
# Faherty                   1.962350
# M.M.LaFleur               1.942792
# Janessa Leone             1.823812
# Araks                     1.761878
# Sea                       1.716242
# BROCHU WALKER             1.631489
# Tanya Taylor              1.615190
# Clare V.                  1.502730
# Nili Lotan                1.168609
# Les Girls Les Boys        1.132752
# Prism                     1.087116
# Sandy Liang               1.080597
# 6397                      1.062668
# Ancient Greek Sandals     1.007253
# Alo Yoga                  0.855676
# Collina Strada            0.816559
# Whit                      0.797001
# Name: brand, dtype: float64

# %%
# Split features and response variables

X=cleaned_data['details']+' '+cleaned_data['description']
y=cleaned_data['brand'].astype(str)

# %%
# Covert categorical labels into numerical values

from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y = to_categorical(encoder.fit_transform(y))

# %%
# Count vetorize all the features

from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(ngram_range=(1, 1), 
                             stop_words="english" 
                             ,max_features=3000
                             ,token_pattern=r'\b[a-zA-Z]{3,}\b'
                            )
X=vectorizer.fit_transform(X)
X = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2, stratify=y)

# %% [markdown]
# ## Build a Random Forest Model without Additional Feature Engineering

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

clf_rf = RandomForestClassifier(random_state=1, n_estimators = 200) 
clf_rf.fit(X_train, y_train)
y_pred_rf = clf_rf.predict(X_test)
score_test_rf = accuracy_score(y_test, y_pred_rf) 
print(score_test_rf)
# Out:
# 0.8758862358405998

# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
import numpy as np
import string
from nltk.corpus import stopwords
from nltk import word_tokenize
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from keras.utils import to_categorical
from keras.preprocessing.text import Tokenizer
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
cleaned_data=pd.read_csv('after_feature_creation.csv')

# %%
cleaned_data.columns
# Out:
# Index(['product_id', 'brand', 'brand_category', 'name', 'details',
#        'description', 'value_brand', 'bio', 'quote', 'quote_attribute',
#        'intro', 'lifestyle_copy', 'short_bio', 'listing_bio', 'attribute_pair',
#        'manuf_location', 'is_handmade', 'is_artisan_crafted', 'is_sustainable',
#        'is_emerging', 'is_vegan', 'is_BIPOC', 'is_woman_owned', 'is_beach',
#        'is_city', 'is_holiday', 'is_romance', 'is_chic', 'is_comfortable',
#        'is_weekday', 'is_asymmetrical', 'is_timeless', 'is_classic', 'is_swim',
#        'is_casual', 'is_pajama', 'is_sophisticated', 'is_modern', 'material'],
#       dtype='object')

# %%
# Data for building classification models

model_data=cleaned_data[['brand','brand_category','details','description','manuf_location','is_beach'
                        ,'is_city', 'is_holiday', 'is_romance', 'is_chic', 'is_comfortable',
                       'is_weekday', 'is_asymmetrical', 'is_timeless', 'is_classic', 'is_swim',
                       'is_casual', 'is_pajama', 'is_sophisticated', 'is_modern', 'material']]
model_data
# Out:
#                 brand        brand_category  \
# 0                 Two         UNKNOWN_TOKEN
# 1      Collina Strada         UNKNOWN_TOKEN
# 2             Cariuma         UNKNOWN_TOKEN
# 3             Cariuma         UNKNOWN_TOKEN
# 4             Cariuma         UNKNOWN_TOKEN
# ...               ...                   ...
# 61350         Nomasei          SandalsSales
# 61351         Nomasei  Flat sandalsArchives
# 61352         Nomasei  Flat sandalsArchives
# 61353         Nomasei          SandalsSales
# 61354         Nomasei  Flat sandalsArchives
#
#                                                  details  \
# 0                                          UNKNOWN_TOKEN
# 1                                          UNKNOWN_TOKEN
# 2                                          UNKNOWN_TOKEN
# 3                                          UNKNOWN_TOKEN
# 4                                          UNKNOWN_TOKEN
# ...                                                  ...
# 61350  feminine flat mule Square shape v line front g...
# 61351  feminine flat mule Square shape v line front g...
# 61352  feminine flat mule Square shape v line front g...
# 61353  feminine flat mule Square shape v line front g...
# 61354  feminine flat mule Square shape v line front g...
#
#                                              description manuf_location  \
# 0      signature khadi shirt available black white ea...  UNKNOWN_TOKEN
# 1      mid length dress ruffle adjustable strap bias ...       New York
# 2                    ibi slip Raw Red Knit Sneaker woman  UNKNOWN_TOKEN
# 3                      ibi slip Black Knit Sneaker woman  UNKNOWN_TOKEN
# 4                                          UNKNOWN_TOKEN  UNKNOWN_TOKEN
# ...                                                  ...            ...
# 61350  flat BowVida mule black suede ideal spring sum...  UNKNOWN_TOKEN
# 61351  flat Vida mule tangerine suede comfortable fem...  UNKNOWN_TOKEN
# 61352  flat BowVida mule fuschia suede ideal spring s...  UNKNOWN_TOKEN
# 61353  flat Vida mule silver metalized leather comfor...  UNKNOWN_TOKEN
# 61354  flat BowVida mule bronze leather ideal spring ...  UNKNOWN_TOKEN
#
#        is_beach  is_city  is_holiday  is_romance  is_chic  ...  is_weekday  \
# 0          True     True       False       False    False  ...       False
# 1         False    False       False       False    False  ...       False
# 2         False    False       False       False    False  ...       False
# 3         False    False       False       False    False  ...       False
# 4         False    False       False       False    False  ...       False
# ...         ...      ...         ...         ...      ...  ...         ...
# 61350     False    False       False       False    False  ...       False
# 61351     False    False       False       False    False  ...       False
# 61352     False    False       False       False    False  ...       False
# 61353     False    False       False       False    False  ...       False
# 61354     False    False       False       False    False  ...       False
#
#        is_asymmetrical  is_timeless  is_classic  is_swim  is_casual  \
# 0                False        False       False    False      False
# 1                False        False       False    False      False
# 2                False        False       False    False      False
# 3                False        False       False    False      False
# 4                False        False       False    False      False
# ...                ...          ...         ...      ...        ...
# 61350            False        False       False    False      False
# 61351            False        False       False    False      False
# 61352            False        False       False    False      False
# 61353            False        False       False    False      False
# 61354            False        False       False    False      False
#
#        is_pajama  is_sophisticated  is_modern       material
# 0          False             False      False  UNKNOWN_TOKEN
# 1          False             False      False       100 rose
# 2          False             False      False  UNKNOWN_TOKEN
# 3          False             False      False  UNKNOWN_TOKEN
# 4          False             False      False  UNKNOWN_TOKEN
# ...          ...               ...        ...            ...
# 61350      False             False      False  UNKNOWN_TOKEN
# 61351      False             False      False  UNKNOWN_TOKEN
# 61352      False             False      False  UNKNOWN_TOKEN
# 61353      False             False      False  UNKNOWN_TOKEN
# 61354      False             False      False  UNKNOWN_TOKEN
#
# [61355 rows x 21 columns]

# %%
model_data2=cleaned_data[['brand','brand_category','details','description','name','attribute_pair','manuf_location','is_beach'
                        ,'is_city', 'is_holiday', 'is_romance', 'is_chic', 'is_comfortable',
                       'is_weekday', 'is_asymmetrical', 'is_timeless', 'is_classic', 'is_swim',
                       'is_casual', 'is_pajama', 'is_sophisticated', 'is_modern', 'material']]
model_data2
# Out:
#                 brand        brand_category  \
# 0                 Two         UNKNOWN_TOKEN
# 1      Collina Strada         UNKNOWN_TOKEN
# 2             Cariuma         UNKNOWN_TOKEN
# 3             Cariuma         UNKNOWN_TOKEN
# 4             Cariuma         UNKNOWN_TOKEN
# ...               ...                   ...
# 61350         Nomasei          SandalsSales
# 61351         Nomasei  Flat sandalsArchives
# 61352         Nomasei  Flat sandalsArchives
# 61353         Nomasei          SandalsSales
# 61354         Nomasei  Flat sandalsArchives
#
#                                                  details  \
# 0                                          UNKNOWN_TOKEN
# 1                                          UNKNOWN_TOKEN
# 2                                          UNKNOWN_TOKEN
# 3                                          UNKNOWN_TOKEN
# 4                                          UNKNOWN_TOKEN
# ...                                                  ...
# 61350  feminine flat mule Square shape v line front g...
# 61351  feminine flat mule Square shape v line front g...
# 61352  feminine flat mule Square shape v line front g...
# 61353  feminine flat mule Square shape v line front g...
# 61354  feminine flat mule Square shape v line front g...
#
#                                              description  \
# 0      signature khadi shirt available black white ea...
# 1      mid length dress ruffle adjustable strap bias ...
# 2                    ibi slip Raw Red Knit Sneaker woman
# 3                      ibi slip Black Knit Sneaker woman
# 4                                          UNKNOWN_TOKEN
# ...                                                  ...
# 61350  flat BowVida mule black suede ideal spring sum...
# 61351  flat Vida mule tangerine suede comfortable fem...
# 61352  flat BowVida mule fuschia suede ideal spring s...
# 61353  flat Vida mule silver metalized leather comfor...
# 61354  flat BowVida mule bronze leather ideal spring ...
#
#                                                     name attribute_pair  \
# 0                 Khadi Stripe Shirt-our signature shirt  UNKNOWN_TOKEN
# 1          RUFFLE MARKET DRESS LOOPY PINK SISTINE TOMATO  UNKNOWN_TOKEN
# 2                 IBI Slip On Raw Red Knit Sneaker Women  UNKNOWN_TOKEN
# 3                   IBI Slip On Black Knit Sneaker Women  UNKNOWN_TOKEN
# 4      CATIBA PRO Skate Black Suede and Canvas Contra...  UNKNOWN_TOKEN
# ...                                                  ...            ...
# 61350                BowVida Mule in Black Suede Kidskin  UNKNOWN_TOKEN
# 61351       Sandale Vida Mule In Tangerine Suede Kidskin  UNKNOWN_TOKEN
# 61352              BowVida Mule in Fuschia Suede Kidskin  UNKNOWN_TOKEN
# 61353              Vida Mule in Silver Metalized Leather  UNKNOWN_TOKEN
# 61354           BowVida Mule in Bronze Metalized Leather  UNKNOWN_TOKEN
#
#       manuf_location  is_beach  is_city  is_holiday  ...  is_weekday  \
# 0      UNKNOWN_TOKEN      True     True       False  ...       False
# 1           New York     False    False       False  ...       False
# 2      UNKNOWN_TOKEN     False    False       False  ...       False
# 3      UNKNOWN_TOKEN     False    False       False  ...       False
# 4      UNKNOWN_TOKEN     False    False       False  ...       False
# ...              ...       ...      ...         ...  ...         ...
# 61350  UNKNOWN_TOKEN     False    False       False  ...       False
# 61351  UNKNOWN_TOKEN     False    False       False  ...       False
# 61352  UNKNOWN_TOKEN     False    False       False  ...       False
# 61353  UNKNOWN_TOKEN     False    False       False  ...       False
# 61354  UNKNOWN_TOKEN     False    False       False  ...       False
#
#        is_asymmetrical  is_timeless  is_classic  is_swim  is_casual  \
# 0                False        False       False    False      False
# 1                False        False       False    False      False
# 2                False        False       False    False      False
# 3                False        False       False    False      False
# 4                False        False       False    False      False
# ...                ...          ...         ...      ...        ...
# 61350            False        False       False    False      False
# 61351            False        False       False    False      False
# 61352            False        False       False    False      False
# 61353            False        False       False    False      False
# 61354            False        False       False    False      False
#
#        is_pajama  is_sophisticated  is_modern       material
# 0          False             False      False  UNKNOWN_TOKEN
# 1          False             False      False       100 rose
# 2          False             False      False  UNKNOWN_TOKEN
# 3          False             False      False  UNKNOWN_TOKEN
# 4          False             False      False  UNKNOWN_TOKEN
# ...          ...               ...        ...            ...
# 61350      False             False      False  UNKNOWN_TOKEN
# 61351      False             False      False  UNKNOWN_TOKEN
# 61352      False             False      False  UNKNOWN_TOKEN
# 61353      False             False      False  UNKNOWN_TOKEN
# 61354      False             False      False  UNKNOWN_TOKEN
#
# [61355 rows x 23 columns]

# %% [markdown]
# ## Additional Preprocessing

# %%
# Remove special stopwords like 'description', 'details', 'product', 'item'

model_data['details']=model_data['details'].str.replace(r'\b(descriptions?|details?|products?|items?)\b','',case=False)
model_data['description']=model_data['description'].str.replace(r'\b(descriptions?|details?|products?|items?)\b','',case=False)
# Out:
# <ipython-input-6-c96d497d811c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data['details']=model_data['details'].str.replace(r'\b(descriptions?|details?|products?|items?)\b','',case=False)
# <ipython-input-6-c96d497d811c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data['description']=model_data['description'].str.replace(r'\b(descriptions?|details?|products?|items?)\b','',case=False)

# %%
# Data Cleaning on the "brand_category" field

def removePunctuation(text, punctuations=string.punctuation+"``"+"’"+"”"):
    words=nltk.word_tokenize(text)
    newWords = [word for word in words if word.lower() not in punctuations]
    cleanedText = " ".join(newWords)
    return cleanedText

nltk_stopwords = set(stopwords.words("English"))
def removeStopwords(text, stopwords=nltk_stopwords):
    words = nltk.word_tokenize(text)
    newWords = [word for word in words if word.lower() not in stopwords]
    cleanedText = " ".join(newWords)
    return cleanedText

# Perform lemmatization

import nltk
from nltk.stem import WordNetLemmatizer

def lemm(data):

    lemmatizer = WordNetLemmatizer()
    sentences = []
    
    for i in data:
        tokens = nltk.word_tokenize(i)
        words = []
        for word in tokens:
            words.append(lemmatizer.lemmatize(word))
        sentence = " ".join(words)
        sentences.append(sentence)
    return sentences

# %%
model_data['brand_category']=model_data['brand_category'].apply(removePunctuation)
model_data['brand_category']=model_data['brand_category'].apply(removeStopwords)
# Out:
# <ipython-input-8-c76d1dc16c9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data['brand_category']=model_data['brand_category'].apply(removePunctuation)
# <ipython-input-8-c76d1dc16c9b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data['brand_category']=model_data['brand_category'].apply(removeStopwords)

# %%
model_data['brand_category']=lemm(model_data['brand_category'])
# Out:
# <ipython-input-9-5b45bdea018a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data['brand_category']=lemm(model_data['brand_category'])

# %%
# Get top 50 brands and classify the other brands as 'Others'

top_50_label = model_data.groupby('brand')['brand'].count().sort_values(ascending=False).head(50).index.values

for i in range(len(model_data)):
    if model_data.iloc[i,0] in top_50_label:
        continue
    else:
        model_data.iloc[i,0]='Others'
# Out:
# /Users/crystal/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
model_data.groupby('brand')['brand'].count().sort_values(ascending=False).head(50)
# Out:
# brand
# 7 For All Mankind        9011
# Others                   8744
# Rails                    2864
# Intentionally Blank      2534
# A.L.C.                   2092
# Rachel Comey             2081
# Misa                     2030
# Studio 189               1956
# ASTR the Label           1942
# lemlem                   1821
# Simon Miller             1451
# Cynthia Rowley           1347
# Outerknown               1338
# Chufy                    1209
# Faherty                  1204
# M.M.LaFleur              1192
# Janessa Leone            1119
# Araks                    1081
# Sea                      1053
# BROCHU WALKER            1001
# Tanya Taylor              991
# Clare V.                  922
# Nili Lotan                717
# Les Girls Les Boys        695
# Prism                     667
# Sandy Liang               663
# 6397                      652
# Ancient Greek Sandals     618
# Alo Yoga                  525
# Collina Strada            501
# Whit                      489
# Batsheva                  484
# Jenni Kayne               483
# Varley US                 447
# Frame                     406
# Aesther Ekme              388
# Andrea Iyamah             367
# Want Les Essentiels       355
# Mother Denim              340
# ANINE BING                338
# ATP Atelier               327
# Cariuma                   324
# Ciao Lucia                319
# Gigi Burris               303
# Christina Lehr            301
# Esquivel                  294
# Two                       284
# Eleven Six                280
# Citizens of Humanity      278
# EMME PARSONS              267
# Name: brand, dtype: int64

# %%
# Pull response variable
# Covert categorical labels into numerical values

y=model_data['brand'].astype(str)
encoder = LabelEncoder()
y = to_categorical(encoder.fit_transform(y))

# Convert y to 1-D array
def get_new_labels(y):
    y_new = LabelEncoder().fit_transform([''.join(str(l)) for l in y])
    return y_new

y_new = get_new_labels(y)

# %%
encoder.classes_
# Out:
# array(['6397', '7 For All Mankind', 'A.L.C.', 'ANINE BING',
#        'ASTR the Label', 'ATP Atelier', 'Aesther Ekme', 'Alo Yoga',
#        'Ancient Greek Sandals', 'Andrea Iyamah', 'Araks', 'BROCHU WALKER',
#        'Banjanan', 'Batsheva', 'Cariuma', 'Christina Lehr', 'Chufy',
#        'Ciao Lucia', 'Citizens of Humanity', 'Clare V.', 'Collina Strada',
#        'Cynthia Rowley', 'EMME PARSONS', 'Eleven Six', 'Esquivel',
#        'Faherty', 'Frame', 'Gigi Burris', 'Intentionally Blank',
#        'Janessa Leone', 'Jenni Kayne', 'Les Girls Les Boys',
#        'M.M.LaFleur', 'Misa', 'Mother Denim', 'Nili Lotan', 'Others',
#        'Outerknown', 'Prism', 'Rachel Comey', 'Rails', 'Sandy Liang',
#        'Sea', 'Simon Miller', 'Studio 189', 'Tanya Taylor', 'Two',
#        'Varley US', 'Want Les Essentiels', 'Whit', 'lemlem'], dtype=object)

# %%
y_new
# Out:
# array([ 4, 30, 36, ..., 14, 14, 14])

# %% [markdown]
# ## Building Random Forest Models

# %%
X=model_data['details']+' '+model_data['description']+' '+model_data['brand_category']

# %%
X
# Out:
# 0        UNKNOWN_TOKEN signature khadi shirt available ...
# 1        UNKNOWN_TOKEN mid length dress ruffle adjustab...
# 2        UNKNOWN_TOKEN ibi slip Raw Red Knit Sneaker wo...
# 3        UNKNOWN_TOKEN ibi slip Black Knit Sneaker woma...
# 4                UNKNOWN_TOKEN UNKNOWN_TOKEN UNKNOWN_TOKEN
#                                ...
# 61350    feminine flat mule Square shape v line front g...
# 61351    feminine flat mule Square shape v line front g...
# 61352    feminine flat mule Square shape v line front g...
# 61353    feminine flat mule Square shape v line front g...
# 61354    feminine flat mule Square shape v line front g...
# Length: 61355, dtype: object

# %%
X2=model_data2['details']+' '+model_data2['description']+' '+model_data2['brand_category']+' '+model_data2['name']+' '+model_data2['attribute_pair']

# %%
X2
# Out:
# 0        UNKNOWN_TOKEN signature khadi shirt available ...
# 1        UNKNOWN_TOKEN mid length dress ruffle adjustab...
# 2        UNKNOWN_TOKEN ibi slip Raw Red Knit Sneaker wo...
# 3        UNKNOWN_TOKEN ibi slip Black Knit Sneaker woma...
# 4        UNKNOWN_TOKEN UNKNOWN_TOKEN UNKNOWN_TOKEN CATI...
#                                ...
# 61350    feminine flat mule Square shape v line front g...
# 61351    feminine flat mule Square shape v line front g...
# 61352    feminine flat mule Square shape v line front g...
# 61353    feminine flat mule Square shape v line front g...
# 61354    feminine flat mule Square shape v line front g...
# Length: 61355, dtype: object

# %% [markdown]
# ### Count Vectorization on Brand_Category, Details, and Description

# %%
# Count vetorize all the features

vectorizer = CountVectorizer(ngram_range=(1, 1), 
                             stop_words="english" 
                             ,max_features=3000
                             ,token_pattern=r'\b[a-zA-Z]{3,}\b'
                            )
X_cv1=vectorizer.fit_transform(X)
X_cv1= pd.DataFrame(X_cv1.toarray(), columns=vectorizer.get_feature_names())

# %%
vectorizer = CountVectorizer(ngram_range=(1, 1), 
                             stop_words="english" 
                             ,max_features=5000
                             ,token_pattern=r'\b[a-zA-Z]{3,}\b'
                            )
X2_cv1=vectorizer.fit_transform(X2)
X2_cv1= pd.DataFrame(X2_cv1.toarray(), columns=vectorizer.get_feature_names())

# %%
vectorizer = CountVectorizer(ngram_range=(1, 1), 
                             stop_words="english" 
                             ,max_features=600
                             ,token_pattern=r'\b[a-zA-Z]{3,}\b'
                            )
X3_cv1=vectorizer.fit_transform(X2)
X3_cv1= pd.DataFrame(X3_cv1.toarray(), columns=vectorizer.get_feature_names())

# %%
vectorizer = CountVectorizer(ngram_range=(1, 1), 
                             stop_words="english" 
                             ,max_features=300
                             ,token_pattern=r'\b[a-zA-Z]{3,}\b'
                            )
X4_cv1=vectorizer.fit_transform(X2)
X4_cv1= pd.DataFrame(X4_cv1.toarray(), columns=vectorizer.get_feature_names())

# %% [markdown]
# ### TF-IDF on Brand_Category, Details, and Description

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,1),
                             token_pattern=r'\b[a-zA-Z]{3,}\b',
                             max_features=3000)
X_tfidf1 = vectorizer.fit_transform(X)
X_tfidf1 = pd.DataFrame(X_tfidf1.toarray(), columns=vectorizer.get_feature_names())

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,1),
                             token_pattern=r'\b[a-zA-Z]{3,}\b',
                             max_features=5000)
X2_tfidf1 = vectorizer.fit_transform(X2)
X2_tfidf1 = pd.DataFrame(X2_tfidf1.toarray(), columns=vectorizer.get_feature_names())

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,1),
                             token_pattern=r'\b[a-zA-Z]{3,}\b',
                             max_features=600)
X3_tfidf1 = vectorizer.fit_transform(X2)
X3_tfidf1 = pd.DataFrame(X3_tfidf1.toarray(), columns=vectorizer.get_feature_names())

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,1),
                             token_pattern=r'\b[a-zA-Z]{3,}\b',
                             max_features=3000)
X4_tfidf1 = vectorizer.fit_transform(X2)
X4_tfidf1 = pd.DataFrame(X4_tfidf1.toarray(), columns=vectorizer.get_feature_names())

# %% [markdown]
# ### One-Hot Encoding on New Features

# %%
X_new=pd.get_dummies(data=model_data
                     ,columns=['manuf_location','is_beach'
                                    ,'is_city', 'is_holiday', 'is_romance', 'is_chic', 'is_comfortable',
                                   'is_weekday', 'is_asymmetrical', 'is_timeless', 'is_classic', 'is_swim',
                                   'is_casual', 'is_pajama', 'is_sophisticated', 'is_modern', 'material']
                     ,drop_first=True)

# %%
X_new=X_new.drop(['brand','brand_category','details','description'],axis=1)

# %%
X_cv2= pd.concat([X_cv1, X_new], axis=1, join='inner')

# %%
X_tfidf2=pd.concat([X_tfidf1, X_new], axis=1, join='inner')

# %%
X2_cv2= pd.concat([X2_cv1, X_new], axis=1, join='inner')

# %%
X2_tfidf2=pd.concat([X2_tfidf1, X_new], axis=1, join='inner')

# %%
X3_tfidf2=pd.concat([X3_tfidf1, X_new], axis=1, join='inner')

# %%
X4_tfidf2=pd.concat([X4_tfidf1, X_new], axis=1, join='inner')

# %%
X3_cv2=pd.concat([X3_cv1, X_new], axis=1, join='inner')

# %%
X4_cv2=pd.concat([X4_cv1, X_new], axis=1, join='inner')

# %% [markdown]
# ### Dimensionality Reduction

# %%
pca1 = PCA(n_components=10)
pca2 = PCA(n_components=0.9)

X_cv2_pca1 = pca1.fit_transform(X_cv2)
X_cv2_pca2 = pca2.fit_transform(X_cv2)

X_tfidf2_pca1 = pca1.fit_transform(X_tfidf2)
X_tfidf2_pca2 = pca2.fit_transform(X_tfidf2)

# %% [markdown]
# ### Cross-Validation

# %%
kfolds = StratifiedKFold(n_splits = 10, random_state = 1, shuffle = True)

# %%
clf_rf = RandomForestClassifier(random_state=1, n_estimators = 100, criterion='gini')

# %%
error_model_1_cv = cross_val_score(clf_rf, X_cv1,y_new, cv=kfolds, scoring = 'accuracy')

# %%
error_model_2_cv = cross_val_score(clf_rf, X_tfidf1,y_new, cv=kfolds, scoring = 'accuracy')

# %%
error_model_3_cv = cross_val_score(clf_rf, X_tfidf2,y_new, cv=kfolds, scoring = 'accuracy')

# %%
error_model_4_cv = cross_val_score(clf_rf, X_cv2,y_new, cv=kfolds, scoring = 'accuracy')

# %%
error_model_5_cv = cross_val_score(clf_rf, X_cv2_pca1,y_new, cv=kfolds, scoring = 'accuracy')

# %%
error_model_6_cv = cross_val_score(clf_rf, X_cv2_pca2,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
error_model_7_cv = cross_val_score(clf_rf, X_tfidf2_pca1,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
error_model_8_cv = cross_val_score(clf_rf, X_tfidf2_pca2,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
error_model_9_cv = cross_val_score(clf_rf, X2_cv2,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
error_model_10_cv = cross_val_score(clf_rf, X2_tfidf2,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
error_model_11_cv = cross_val_score(clf_rf, X3_tfidf2,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
error_model_12_cv = cross_val_score(clf_rf, X4_tfidf2,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
error_model_13_cv = cross_val_score(clf_rf, X3_cv2,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
error_model_14_cv = cross_val_score(clf_rf, X4_cv2,y_new, cv=kfolds, scoring = 'accuracy',n_jobs=-1)

# %%
print("mean accuracy for model_1_cv:",np.mean(error_model_1_cv)) # -> Count Vectorization without Adding New Features
print("mean accuracy for model_2_cv:",np.mean(error_model_2_cv)) # -> TF-IDF without Adding New Features
print("mean accuracy for model_3_cv:",np.mean(error_model_3_cv)) # -> TF-IDF + New Features
print("mean accuracy for model_4_cv:",np.mean(error_model_4_cv)) # -> Count Vectorization + New Features
print("mean accuracy for model_5_cv:",np.mean(error_model_5_cv)) # -> Count Vectorization + New Features +PCA(comp=10)
print("mean accuracy for model_6_cv:",np.mean(error_model_6_cv)) # -> Count Vectorization + New Features +PCA(comp=0.9)
print("mean accuracy for model_7_cv:",np.mean(error_model_7_cv)) # -> TF-IDF + New Features +PCA(comp=10)
print("mean accuracy for model_8_cv:",np.mean(error_model_8_cv)) # -> TF-IDF + New Features +PCA(comp=0.9)
print("mean accuracy for model_9_cv:",np.mean(error_model_9_cv)) # -> Count Vectorization（5000 features） on All Text + New Features

# %%
print("mean accuracy for model_10_cv:",np.mean(error_model_10_cv)) # -> TF-IDF (5000 features) on All Text + New Features
# Out:
# mean accuracy for model_10_cv: 0.9594165659875742

# %%
print("mean accuracy for model_11_cv:",np.mean(error_model_11_cv)) # -> TF-IDF (600 features) on All Text + New Features
print("mean accuracy for model_12_cv:",np.mean(error_model_12_cv)) # -> TF-IDF (3000 features) on All Text + New Features

# %%
print("mean accuracy for model_13_cv:",np.mean(error_model_13_cv))
# Out:
# mean accuracy for model_13_cv: 0.9407221480189861

# %%
print("mean accuracy for model_14_cv:",np.mean(error_model_14_cv))
# Out:
# mean accuracy for model_14_cv: 0.9223536487271933

# %% [markdown]
# ## Building RNN Model

# %%
cleaned_data=pd.read_csv('after_feature_creation.csv')

# %%
model_data2=cleaned_data[['brand','brand_category','details','description','name','attribute_pair','manuf_location','is_beach'
                        ,'is_city', 'is_holiday', 'is_romance', 'is_chic', 'is_comfortable',
                       'is_weekday', 'is_asymmetrical', 'is_timeless', 'is_classic', 'is_swim',
                       'is_casual', 'is_pajama', 'is_sophisticated', 'is_modern', 'material']]

# %%
top_50_label = model_data2.groupby('brand')['brand'].count().sort_values(ascending=False).head(50).index.values

for i in range(len(model_data2)):
    if model_data2.iloc[i,0] in top_50_label:
        continue
    else:
        model_data2.iloc[i,0]='Others'
# Out:
# /Users/crystal/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
def removePunctuation(text, punctuations=string.punctuation+"``"+"’"+"”"):
    words=nltk.word_tokenize(text)
    newWords = [word.lower() for word in words if word.lower() not in punctuations]
    cleanedText = " ".join(newWords)
    return cleanedText

# Perform lemmatization

import nltk
from nltk.stem import WordNetLemmatizer

def lemm(data):

    lemmatizer = WordNetLemmatizer()
    sentences = []
    
    for i in data:
        tokens = nltk.word_tokenize(i)
        words = []
        for word in tokens:
            words.append(lemmatizer.lemmatize(word))
        sentence = " ".join(words)
        sentences.append(sentence)
    return sentences

# %%
model_data2['brand_category']=model_data2['brand_category'].apply(removePunctuation)
model_data2['details']=model_data2['details'].apply(removePunctuation)
model_data2['description']=model_data2['description'].apply(removePunctuation)
model_data2['name']=model_data2['name'].apply(removePunctuation)
model_data2['attribute_pair']=model_data2['attribute_pair'].apply(removePunctuation)
model_data2['manuf_location']=model_data2['manuf_location'].apply(removePunctuation)
model_data2['material']=model_data2['material'].apply(removePunctuation)
model_data2['brand_category']=lemm(model_data2['brand_category'])
model_data2['details']=lemm(model_data2['details'])
model_data2['description']=lemm(model_data2['description'])
model_data2['name']=lemm(model_data2['name'])
model_data2['attribute_pair']=lemm(model_data2['attribute_pair'])
model_data2['manuf_location']=lemm(model_data2['manuf_location'])
model_data2['material']=lemm(model_data2['material'])
# Out:
# <ipython-input-8-51cdf815bc6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['brand_category']=model_data2['brand_category'].apply(removePunctuation)
# <ipython-input-8-51cdf815bc6a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['details']=model_data2['details'].apply(removePunctuation)
# <ipython-input-8-51cdf815bc6a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['description']=model_data2['description'].apply(removePunctuation)
# <ipython-input-8-51cdf815bc6a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['name']=model_data2['name'].apply(removePunctuation)
# <ipython-input-8-51cdf815bc6a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['attribute_pair']=model_data2['attribute_pair'].apply(removePunctuation)
# <ipython-input-8-51cdf815bc6a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['manuf_location']=model_data2['manuf_location'].apply(removePunctuation)
# <ipython-input-8-51cdf815bc6a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['material']=model_data2['material'].apply(removePunctuation)
# <ipython-input-8-51cdf815bc6a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['brand_category']=lemm(model_data2['brand_category'])
# <ipython-input-8-51cdf815bc6a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['details']=lemm(model_data2['details'])
# <ipython-input-8-51cdf815bc6a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['description']=lemm(model_data2['description'])
# <ipython-input-8-51cdf815bc6a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['name']=lemm(model_data2['name'])
# <ipython-input-8-51cdf815bc6a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['attribute_pair']=lemm(model_data2['attribute_pair'])
# <ipython-input-8-51cdf815bc6a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['manuf_location']=lemm(model_data2['manuf_location'])
# <ipython-input-8-51cdf815bc6a>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_data2['material']=lemm(model_data2['material'])

# %%
labels=model_data2['brand']
docs=model_data2['details']+' '+model_data2['description']+' '+model_data2['brand_category']+' '+model_data2['name']+' '+model_data2['attribute_pair']+' '+model_data2['manuf_location']+' '+model_data2['material']

# %%
encoder = LabelEncoder()
labels = to_categorical(encoder.fit_transform(labels))

# %%
from nltk.corpus import stopwords
import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
from nltk.tokenize import word_tokenize 
from typing import List

stop_words = set(stopwords.words('english')) 
stopwords_removed_docs1 = []
for doc in docs:
  word_tokens = word_tokenize(doc) 
  filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  stopwords_removed_docs1.append(" ".join(filtered_sentence))

# %%
import re
stopwords_removed_docs=[]
for i in stopwords_removed_docs1:
    data=re.sub(r'\b\d+\b', '', i)
#     data=re.sub(r'\b\w{,2}\b','',data)
    stopwords_removed_docs.append(data)

# %%
stopwords_removed_docs
# Out:
# ['unknown_token signature khadi shirt available black white easy wear beach city promise top go warm weather item perfect blazer hand loom woven stripe khadi cotton slightly sheer get soft every wash ship first week april color white black — length  width . — one size fit — grid khadi cotton unknown_token khadi stripe shirt-our signature shirt unknown_token unknown_token unknown_token',
#  'unknown_token mid length dress ruffle adjustable strap bias cut side seam invisible zipper make new york model wear size small  rose sylk rose sylk organic cellulose fiber make natural waste rise bush stem unknown_token ruffle market dress loopy pink sistine tomato unknown_token new york  rose',
#  'unknown_token ibi slip raw red knit sneaker woman unknown_token ibi slip raw red knit sneaker woman unknown_token unknown_token unknown_token',
#  'unknown_token ibi slip black knit sneaker woman unknown_token ibi slip black knit sneaker woman unknown_token unknown_token unknown_token',
#  'unknown_token unknown_token unknown_token catiba pro skate black suede canvas contrast thread ivory logo sneaker woman left unknown_token unknown_token unknown_token',
#  'unknown_token easy smock mini dress gorgeous puff sleeve feel like first day spring belt include  linen model wear size x unknown_token ada unknown_token unknown_token  linen',
#  "unknown_token picture perfect clara stunning linen cover call sandy foot spicy cocktail n't disappoint  linen model wear size s. style dual sizing pick x l unknown_token clara unknown_token unknown_token  linen",
#  "unknown_token well sell bump friendly simone favourite time difficult wear anything else n't say n't warn  cotton model wear size x unknown_token simone unknown_token unknown_token  cotton",
#  'unknown_token super appropriate length bit cold shoulder although stretch back dress snug fit bra needed- yes please consider size  linen model wear size x unknown_token zoe onyx unknown_token unknown_token  linen',
#  'unknown_token something nice jean beginning love affair wrap blouse guipure appliqué sleeve  linen model wear size x unknown_token lubi unknown_token unknown_token  linen',
#  "unknown_token cute open back wo n't stay unnoticed may may new favourite dress  linen model wear size x unknown_token mini caro unknown_token unknown_token  linen",
#  'unknown_token long sleeved linen wrap dress frilly skirt permanently vacation  linen model wear size unknown_token mika unknown_token unknown_token  linen',
#  "unknown_token everybody 's favourite set top feature frilly sleeve lace insert short elasticate waistband keep thing relaxed  linen model wear size x unknown_token claudia onyx unknown_token unknown_token  linen",
#  'unknown_token shani come pair top feature frilly sleeve button back short pocket elasticated waistband power couple also relax could pair short tee two might separation anxiety  cotton eyelet model wear size x unknown_token shani unknown_token unknown_token  cotton',
#  'unknown_token patchwork dream cotton eyelet raksha romper feature frilly sleeve short lace insert close zip back super well put together like  cotton model wear size x unknown_token raksha unknown_token unknown_token  cotton',
#  'unknown_token one signature silhouette back delicate blue white floral print effortless piece craft layer romantic ruffle feature elastic waistband comfortably sit waist slightly curved hem long back accentuate flattering silhouette pair everything white tee coordinate sacha top make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token marion skirt unknown_token usa  poly',
#  'unknown_token new kalita sundress timelessly feminine addition poolside wardrobe handcraft blue shell print chiffon maxi feature adjustable pull string tie shoulder strap tiered skirt small ruffled detail make usa dry clean  poly chiffon measurement size x center front length strap hem . inch model measurement height   waist  bust  hip  model wear size x unknown_token kalita dress unknown_token usa  poly',
#  'unknown_token amata dress signature effortless versatile chiffon maxi silhouette update graphic shell print chiffon feature long blouson sleeve elastic cuff split neckline petal tassel tie figure flattering elasticated waist ruffle detail long skirt finish wide ruffle add romantic charm timeless style make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token amata dress unknown_token usa  poly',
#  'unknown_token handcraft lightweight micro pleated chiffon gorgeous graphic shell print niko pant effortlessly chic style feature band waist elastic back perfect fit partially line complete look coordinate noa top make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token niko pant unknown_token usa  poly',
#  'unknown_token cut micro pleated chiffon loose fit noa top effortlessly chic blouse transition daytime evening feature split neckline signature petal tassel tie long sleeve ruffle trim elastic cuff make usa dry clean  polyester model measurement height   waist  bust  hip  model wear size x unknown_token noa top unknown_token usa  polyester',
#  'unknown_token transition gracefully day evening three quarter sleeve maxi dress feature expertly craft ruffle detail decorate sleeve skirt cut vibrant floral chiffon collared top allow optional opening figure flatter elasticated waistband beautifully tiered skirt make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token pamelina dress unknown_token usa  poly',
#  'unknown_token chiara dress mini length update one classic silhouette cut vibrant floral print chiffon feature deep v neckline long blouson ruched sleeve flattering smocked waist lead mini skirt double ruffle slightly curved hem make usa dry clean  poly chiffon measurement size x center front length . inch model measurement height   waist  bust  hip  model wear size x unknown_token chiara dress unknown_token usa  poly',
#  'unknown_token bella skirt easy wear silhouette handcraft beautiful oasis floral chiffon mini style covered elasticated waist tiered ruffled hem look great dressed basic tee sweater complete look kali sweater coordinate agot top make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token bella skirt unknown_token usa  poly',
#  'unknown_token sweet agot top sleeveless silhouette delicate ruffle trim arm opening split tie neckline signature petal tie cut vibrant floral chiffon feminine top elevate everyday look complete set coordinate bella skirt make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token agot top unknown_token usa  poly',
#  'unknown_token effortless feminine eveleigh dress handcraft soft cotton blend floral print button front closure start neck way length maxi silhouette self tie waist cinch perfect figure flatter fit short puff sleeve foldover collar finish comfortably chic style make usa dry clean  cotton  rayon measurement size x front body length . inch center back length . inch model measurement height   waist  bust  hip  model wear size x unknown_token eveleigh dress unknown_token usa unknown_token',
#  'unknown_token feminine sophisticated lilian dress one popular silhouette feature cap sleeve layered skirt ruffle cut breathable cotton blend gorgeous watercolor floral print sweet mini silhouette detail ruffle trim split neckline finish signature petal tie effortless style perfect weekday getaway dress make usa dry clean  cotton  rayon model measurement height   waist  bust  hip  model wear size x unknown_token lilian dress unknown_token usa unknown_token',
#  'unknown_token elia pant effortlessly chic addition wardrobe cut soft watercolor floral cotton blend elevated jogger style feature split hem tie double side slit pocket partial elasticate waist self tie belt complete chic set coordinate zaayra top make usa dry clean  cotton  rayon model measurement height   waist  bust  hip  model wear size x unknown_token elia pant unknown_token usa unknown_token',
#  'unknown_token zaayra top chic crop blouse deep v neckline wide smocked waist puff sleeve feature elastic cuff tie detail cut watercolor floral print cotton blend top pair perfectly coordinate elia pant make usa dry clean  cotton  rayon model measurement height   waist  bust  hip  model wear size x unknown_token zaayra top unknown_token usa unknown_token',
#  'unknown_token annika mini silhouette feature long ruche flounce sleeve semi sheer top fold collar detail button front double chest pocket ruffle detail smocked elastic waist lead line mini skirt tiered ruffle versatile silhouette cut gorgeous watercolor floral print chiffon make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token annika dress unknown_token usa  poly',
#  'unknown_token tia skirt soft floral chiffon combine unapologetic femininity contemporary draping asymmetrical style feature smocked waistband romantic ruffle line high low hemline pair coordinate ceyla top stunning set make usa dry clean  poly chiffon measurement size x center front length . inch center back length . inch model measurement height   waist  bust  hip  model wear size x unknown_token tia skirt unknown_token usa  poly',
#  'unknown_token chic blouse elevate every day wardrobe ceyla top cut floral cotton blend feature long ballon sleeve lavallière tie wear favorite jean complete look coordinate tia skirt make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token ceyla top unknown_token usa  poly',
#  'unknown_token cut micro pleated chiffon azmina dress effortlessly chic dress hit knee split neckline signature petal tassel tie feature two hook eye closure long blouson sleeve ruffle trim elastic cuff make usa dry clean  polyester model measurement height   waist  bust  hip  model wear size x unknown_token azmina dress unknown_token usa  polyester',
#  'unknown_token kali new knit sweatshirt cut cozy cotton cashmere blend feature voluminous gather long sleeve fit cuff ribbed hem ribbed crew neckline sure wardrobe staple pair style everything jean one skirt make china dry clean  cotton  cashmere model measurement height   waist  bust  hip  model wear size x unknown_token kali sweater unknown_token china unknown_token',
usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token martina skirt unknown_token usa  poly',
#  'unknown_token charly encapsulate modern elegance comfortable button top handcrafted satin tie dye print lightweight stylish short sleeve top feature notched collar pair well jean coordinate aidan short make usa dry clean  poly satin model measurement height   waist  bust  hip  model wear size x unknown_token charly top unknown_token usa  poly',
#  'unknown_token new chrissy top handcraft comfortable cotton blend elegant tile print flattering silhouette perfect season beyond feature layered flutter sleeve signature string petal tie easy wear blouse pair favorite denim elevate everyday look make usa dry clean  rayon  cotton model measurement height   waist  bust  hip  model wear size x unknown_token chrissy top unknown_token usa unknown_token',
#  'unknown_token simply chic anita top effortless every day blouse craft delicate semi sheer floral print chiffon button blouse collar feature long sleeve smocked cuff feminine ruffled trim make usa dry clean  poly chiffon model measurement height   waist  bust  hip  model wear size x unknown_token candra top unknown_token usa  poly',
#  'unknown_token detail super cozy lightweight jersey warm ivory pajama set short sleeve buttondown shirt elastic waist drawstre short feature green palm tree print pajama style notched collar patch pocket chest white piping trim relaxed fit make smooth ultra soft rayon blend fabric stretchy jersey knit stylish sleepwear want live day long  rayon  spandex import care hand wash cold hang dry bleach fit recommend order true size body length top  / measure small inseam length short  front rise length  / model wear size s. model measurement height   bust  waist  hip  / unknown_token nessa botanical palm unknown_token unknown_token unknown_token',
#  'unknown_token rc staple mid heel bootie make comeback fall new colorway . shaft height take size  nappa leather make peru • • unknown_token sonora boot unknown_token peru unknown_token',
#  'feminine sandal stable chunky heel square shape feminine cut size foot v throat line refine silhouette elongate ankle adjustable slingback strap thank signature bow upper metalized sheepskin line goatskin leather outsole leather  cm chunky heel cover leather block heel bronze adora sandal ideal spring summer shoe party wedding ceremony sustainable luxury brand nomasei sandal adora sandal bronze metalized leather unknown_token unknown_token unknown_token',
#  'unknown_token item detail heel measure approximately  mm  inch color black suede effect outer  cotton  polyester  polyurethane sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose  bio base mass content make italy size fit care fit small size one half size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf gaby black suede effect following impact environment work offset impact  global warming potential gwo . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token gaby unknown_token italy unknown_token',
#  'unknown_token item detail heel measure approximately  mm . inch color fuchsia python effect outer  polyester  polyurethane sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose make italy size fit care fit small size one full size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf lily fuchsia python effect following impact environment work offset impact  global warming potential gwo . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token lily unknown_token italy unknown_token',
#  'unknown_token item detail heel measure approximately  mm . inch color black suede effect outer  cotton  polyester  polyurethane sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose make italy size fit care fit true size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf tina black suede effect following impact environment work offset impact  global warming potential gwo . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token tina unknown_token italy unknown_token',
#  'mid rise size order one size = = = = = = = =  =  unknown_token unknown_token caden crop twill trouser primarycolor white materialclothing synthetic materialclothing cottonblend style androgynous style casual style classic primarycolor pink style classic materialclothing cottonblend style casual style androgynous materialclothing synthetic classpantsandleggings trouser classpantsandleggings trouser occasion daytonight occasion daytonight sizing regular sizing regular category bottom category bottom lengthpantsandleggings cropped lengthpantsandleggings cropped rise mid89 rise mid89 gender woman gender woman drycleanonly drycleanonly fit fittedtailored fit fittedtailored occasion weekend occasion weekend subcategorybottom pantsleggings subcategorybottom pantsleggings unknown_token unknown_token',
#  'unknown_token item detail heel measure approximately  mm . inch color nude patent effect outer  polyester  polyurethane sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose lightly cushioned insole make italy size fit care fit small size one half size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf eliza nude patent effect following impact environment work offset impact  global warming potential gwp . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token eliza unknown_token italy unknown_token',
#  'unknown_token item detail heel measure approximately  mm  inch color cuoio python effect outer  polyester  polyurethane sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose lightly cushioned insole make italy size fit care fit true size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf sally cuoio python effect following impact environment work offset impact  global warming potential gwo . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token sally unknown_token italy unknown_token',
#  'unknown_token description kyoto mini handbag compact bag cross body bag perfect size evening bag great run around town big enough fit essential two compartment divide zipped pouch one small front pocket bag close exclusive prism gunmetal turn lock finish long leather gunmetal chain strap tuck long strap create mini clutch bag measurement  cm wide x  cm high  cm deep strap  cm long unknown_token kyoto mini handbag unknown_token unknown_token unknown_token',
#  'detail |distressed denim boyfriend jean button fly. cotton import care |machine wash cold tumble dry low fit |loose fit recommend order true size inseam  / measure size  unknown_token pant beckett unknown_token unknown_token unknown_token',
#  'detail distressed denim boyfriend jean button fly  cotton import care machine wash cold tumble dry low fit loose fit recommend order true size inseam  / measure size  unknown_token pant beckett unknown_token unknown_token unknown_token',
#  'unknown_token finally elevated basic subtly succinctly communicate take number situation gold standard classic fit inspire favorite vintage shirt crew neck straight cut fall hip make scratch los angeles fabric super soft baby gauge jerseycolor whitecontent  cottoncare machine wash cold tumble dry low dry clean model   wear size unknown_token bullshit unknown_token unknown_token  cottoncare',
#  'unknown_token although original design intent certainly understandable find graphic sexually suggestive way gold standard classic fit inspire favorite vintage shirt crew neck straight cut fall hip make scratch los angeles fabric super soft baby gauge jerseycolor whitecontent  cotton care machine wash cold tumble dry low dry clean model   wear size unknown_token nude unknown_token unknown_token  cotton',
#  "unknown_token mon cheri mon amour monogram gold standard classic fit inspire favorite vintage shirt crew neck straight cut fall hip make scratch los angeles fabric super soft baby gauge jerseycolor blackcontent  cottoncare machine wash cold tumble dry low dry clean model ' wear size unknown_token amour unknown_token unknown_token  cottoncare",
#  'detail |super soft cozy long sleeve plaid button top sleep shirt. rayon import care |hand wash cold hang dry fit |recommend order true size unknown_token sleepwear sleep shirt unknown_token unknown_token unknown_token',
#  'unknown_token item detail heel measure approximately  mm  inch color patchwork python effect outer  polyester  polyamide sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose lightly cushioned insole make italy size fit care fit true size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf amelia patchwork python effect following impact environment work offset impact  global warming potential gwp . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token amelia unknown_token italy unknown_token',
#  'unknown_token item detail heel measure approximately  mm . inch color patchwork python effect outer  polyester  polyamide sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose lightly cushioned insole make italy size fit care fit small size one half size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf audrey patchwork python effect following impact environment work offset impact  global warming potential gwp . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token audrey unknown_token italy unknown_token',
#  'unknown_token item detail heel measure approximately  mm  inch  mm  inch platform  mm  inch pitch color metallic lurex gold mirror ankle strap outer  cotton  polystyrene  polyvinyl sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose make italy size fit care fit true size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf bianca metallic lurex following impact environment work offset impact  global warming potential gwp . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token bianca unknown_token italy unknown_token',
#  'unknown_token item detail heel measure approximately  mm  inch color natural python effect outer  cotton  polyester  polyurethane sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose  bio base mass content make italy size fit care fit true size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf gisele natural python effect following impact environment work offset impact  global warming potential gwo . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_token gisele unknown_token italy unknown_token',
#  'unknown_token item detail heel measure approximately  mm . inch color nude patent effect outer  polyurethane  polyester sole  synthetic rubber  mineral compost  additive lining  polyurethane  viscose lightly cushioned insole make italy size fit care fit true size italian size clean either vegan leather suede upper gently wipe damp cloth careful rub much advise use cleaning product soap polishing treatment may cause damage upper sustainability base cradle consumer life cycle assessment lca conduct sc global service behalf olivia nude patent effect following impact environment work offset impact  global warming potential gwo . kg co2 eq pair drive typical passenger vehicle  mile offset impact  invest green tree reforestation project project date project help reforest one million acre marginal farmland mississippi alluvial valley plant  million tree certify sc global service fresh water consumption fw . m3 pair run typical dishwasher  time offset impact  invest water restoration certificate bonneville environmental foundation primary energy demand ped  mj pair operate typical refrigerator  day impact ozone depletion potential odp acidification potential ap eutrophication potential ep smog photochemical oxidant creation potential pocp fossil fuel depletion ffd furthermore among material various form plastic use make shoe weigh  gram . oz total although already offset offset environmental impact  b plastic originate recycled source acknowledge plastic good planet thus work plastic bank offset plastic use making pair shoe  invest social plastic ® collection credit equal . oz plastic prevent enter ocean recycle finally  material use shoe make italy well manufacturing take place veneto care people make material shoe work supplier manufacturer share embrace value unknown_
#  'heat ready seamless performance knit flat locked seam comfort  way stretch move feel moisture wicking antimicrobial front smooth panel commando comfort high rise hit upper thigh model     waist . hip — wear size x model     waist  hip — wear size l fuel practice trend rip short sculpt seamless performance knit feature edgy slash detail high waist band design wo n budge matter hard work take street oversized top hoodie body map scuplting epic slash detail p.s super breathable design uniquely fit flatter every size wear test house team perfect fit woman ripped short unknown_token unknown_token unknown_token',
#  'ultimate performance fabric moisture wicke antimicrobial technology  way stretch fabric move feel engineer lift sculpt contour smooth body map mesh inset line gusset flatlocked seam wear test , time perfect fit inseam xx  x   . l . high waist high style adorn body map mesh insert high waist lace legging ultimate performance pant moisture wicking antimicrobial innovative construction detail hello flatlock seaming make must essential ..  way stretch fabric move feel moisture wicke antimicrobial technology wear test house team perfect fit engineer lift sculpt contour smooth woman high-waist laced legging unknown_token unknown_token unknown_token',
#  'moisture wicke antimicrobial technology  way stretch fabric move feel fit crop silhouette high neckline bold back strap detail elegant back detail lay flat wear test house team perfect fit move freely studio street troop fitted tank fit crop perfect layer go alo bra high neck stretchy silhouette bold back strap lend elevated touch fit crop silhouette high neck line bold back strap detail woman troop fitted tank unknown_token unknown_token unknown_token',
#  'moisture wicke antimicrobial technology  way stretch fabric move feel ultra modern cropped silhouette extra wide shoulder strap make style functional chic light support wear test house team perfect fit ultra modern ultra cool bind fitted tank new essential cropped silhouette extra wide shoulder strap shelf bra epitome fresh function four way stretch fabric make move along ultra modern cropped silhouette layer beautifully bra choice woman bind fitted bra tank unknown_token unknown_token unknown_token',
#  ...]

# %%
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words=10000, oov_token="UNKNOWN_TOKEN")
tokenizer.fit_on_texts(stopwords_removed_docs)

# %%
def integer_encode_documents(docs, tokenizer):
    return tokenizer.texts_to_sequences(docs)

# %%
from typing import List
def get_max_token_length_per_doc(docs: List[List[str]])-> int:
    return max(list(map(lambda x: len(x.split()), docs)))

# get the max length in terms of token length
max_length = get_max_token_length_per_doc(docs)

# %%
max_length
# Out:
# 654

# %%
from keras.preprocessing.sequence import pad_sequences
MAX_SEQUENCE_LENGTH = 300

encoded_docs = integer_encode_documents(stopwords_removed_docs, tokenizer)

padded_docs = pad_sequences(encoded_docs, maxlen=MAX_SEQUENCE_LENGTH, padding='post')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(padded_docs, labels, test_size=0.2,stratify=labels)

# %%
len(X_train)
# Out:
# 49084

# %%
VOCAB_SIZE = int(len(tokenizer.word_index) * 1.1)

# %%
from numpy import array, argmax, asarray, zeros

def load_glove_vectors():
    embeddings_index = {}
    with open('glove.6B.100d.txt') as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
    print('Loaded %s word vectors.' % len(embeddings_index))
    return embeddings_index


embeddings_index = load_glove_vectors()
# Out:
# Loaded 400000 word vectors.

# %%
tokenizer.word_index
# Out:
# {'UNKNOWN_TOKEN': 1,
#  'unknown': 2,
#  'token': 3,
#  '•': 4,
#  'size': 5,
#  'style': 6,
#  'fit': 7,
#  'make': 8,
#  'wear': 9,
#  'cotton': 10,
#  'model': 11,
#  'dry': 12,
#  'detail': 13,
#  'dress': 14,
#  'waist': 15,
#  'top': 16,
#  'leather': 17,
#  'sleeve': 18,
#  'length': 19,
#  'feature': 20,
#  'clean': 21,
#  'hand': 22,
#  'wash': 23,
#  'fabric': 24,
#  'occasion': 25,
#  'true': 26,
#  'front': 27,
#  'usa': 28,
#  'pocket': 29,
#  'back': 30,
#  'small': 31,
#  'black': 32,
#  'button': 33,
#  'print': 34,
#  'high': 35,
#  'classic': 36,
#  'measurement': 37,
#  'soft': 38,
#  "'s": 39,
#  'design': 40,
#  'hip': 41,
#  'long': 42,
#  'hem': 43,
#  'shoulder': 44,
#  'closure': 45,
#  'care': 46,
#  'woman': 47,
#  'x': 48,
#  'polyester': 49,
#  'bust': 50,
#  'body': 51,
#  'neckline': 52,
#  'cm': 53,
#  'one': 54,
#  'skirt': 55,
#  'look': 56,
#  'pant': 57,
#  'height': 58,
#  'perfect': 59,
#  'neck': 60,
#  'short': 61,
#  'cold': 62,
#  'piece': 63,
#  'shirt': 64,
#  "'": 65,
#  'strap': 66,
#  'tie': 67,
#  'white': 68,
#  'relaxed': 69,
#  'silk': 70,
#  'silhouette': 71,
#  'low': 72,
#  'use': 73,
#  'line': 74,
#  'category': 75,
#  'italy': 76,
#  'side': 77,
#  'color': 78,
#  'cut': 79,
#  'material': 80,
#  'stretch': 81,
#  'sizing': 82,
#  'sweater': 83,
#  'pair': 84,
#  'viscose': 85,
#  'materialclothing': 86,
#  'import': 87,
#  'primarycolor': 88,
#  'gender': 89,
#  'medium': 90,
#  'machine': 91,
#  'rise': 92,
#  'new': 93,
#  'take': 94,
#  'casual': 95,
#  'wool': 96,
#  'leg': 97,
#  'order': 98,
#  'blue': 99,
#  'day': 100,
#  'v': 101,
#  'heel': 102,
#  'denim': 103,
#  'easy': 104,
#  'ankle': 105,
#  'modern': 106,
#  'bottom': 107,
#  'recommend': 108,
#  'weekend': 109,
#  'linen': 110,
#  'ruffle': 111,
#  'tee': 112,
#  'work': 113,
#  'lightweight': 114,
#  'measure': 115,
#  'dye': 116,
#  'elastane': 117,
#  'sandal': 118,
#  'bag': 119,
#  'chest': 120,
#  'slim': 121,
#  'shape': 122,
#  'knit': 123,
#  'rayon': 124,
#  'lining': 125,
#  'zipper': 126,
#  's': 127,
#  'wide': 128,
#  'regular': 129,
#  'feel': 130,
#  'floral': 131,
#  'bleach': 132,
#  'add': 133,
#  'pattern': 134,
#  'inspire': 135,
#  'stripe': 136,
#  'jean': 137,
#  'jacket': 138,
#  'cuff': 139,
#  'daytonight': 140,
#  'shoe': 141,
#  'zip': 142,
#  'adjustable': 143,
#  'finish': 144,
#  'signature': 145,
#  'organic': 146,
#  'hang': 147,
#  'belt': 148,
#  'tumble': 149,
#  'mini': 150,
#  'like': 151,
#  'flat': 152,
#  'trim': 153,
#  'drycleanonly': 154,
#  'comfort': 155,
#  'garment': 156,
#  'create': 157,
#  'go': 158,
#  'skinny': 159,
#  'natural': 160,
#  'approximately': 161,
#  'vintage': 162,
#  'nylon': 163,
#  'elastic': 164,
#  'layer': 165,
#  'love': 166,
#  'sole': 167,
#  'l': 168,
#  'straight': 169,
#  'cashmere': 170,
#  'favorite': 171,
#  'upper': 172,
#  'super': 173,
#  'craft': 174,
#  'wrap': 175,
#  'please': 176,
#  'blend': 177,
#  'suede': 178,
#  'los': 179,
#  'angeles': 180,
#  '—': 181,
#  'inseam': 182,
#  'blouse': 183,
#  'collection': 184,
#  'light': 185,
#  'gold': 186,
#  'lace': 187,
#  'weave': 188,
#  'way': 189,
#  'available': 190,
#  'mm': 191,
#  'good': 192,
#  'collar': 193,
#  'seam': 194,
#  'handmade': 195,
#  'rib': 196,
#  'comfortable': 197,
#  'product': 198,
#  'toe': 199,
#  'slip': 200,
#  'chic': 201,
#  'drop': 202,
#  'additionalcolor': 203,
#  'shoes': 204,
#  'fall': 205,
#  'cool': 206,
#  'sleevelength': 207,
#  'mask': 208,
#  'flattering': 209,
#  'crop': 210,
#  'italian': 211,
#  'polyamide': 212,
#  'midi': 213,
#  'well': 214,
#  'artisan': 215,
#  'large': 216,
#  'pink': 217,
#  'need': 218,
#  'oversized': 219,
#  'two': 220,
#  'item': 221,
#  'give': 222,
#  'full': 223,
#  'slightly': 224,
#  'content': 225,
#  'iron': 226,
#  'feminine': 227,
#  'straw': 228,
#  'waistband': 229,
#  'pull': 230,
#  'inch': 231,
#  'double': 232,
#  'note': 233,
#  'green': 234,
#  'weight': 235,
#  'navy': 236,
#  'hat': 237,
#  'open': 238,
#  'summer': 239,
#  'support': 240,
#  'logo': 241,
#  'china': 242,
#  'recycled': 243,
#  'cropped': 244,
#  'run': 245,
#  'center': 246,
#  'pullover': 247,
#  'contrast': 248,
#  'mid': 249,
#  'tank': 250,
#  'ribbed': 251,
#  'self': 252,
#  'provide': 253,
#  'boot': 254,
#  'time': 255,
#  'multi': 256,
#  'fully': 257,
#  'peru': 258,
#  'puff': 259,
#  'imported': 260,
#  'ethiopia': 261,
#  'bikini': 262,
#  'spandex': 263,
#  'w': 264,
#  'set': 265,
#  'loose': 266,
#  'metallic': 267,
#  'sweatshirt': 268,
#  'keep': 269,
#  'base': 270,
#  'york': 271,
#  'unique': 272,
#  'crew': 273,
#  'water': 274,
#  'every': 275,
#  'crewneck': 276,
#  'origin': 277,
#  'ghana': 278,
#  'offer': 279,
#  'single': 280,
#  'red': 281,
#  'interior': 282,
#  'season': 283,
#  'batik': 284,
#  'sleeveless': 285,
#  'yet': 286,
#  'lengthtop': 287,
#  'sneaker': 288,
#  'deep': 289,
#  'cover': 290,
#  'come': 291,
#  'handle': 292,
#  'block': 293,
#  'edge': 294,
#  'yes': 295,
#  'warm': 296,
#  'bra': 297,
#  'may': 298,
#  'lined': 299,
#  'extra': 300,
#  'sell': 301,
#  'show': 302,
#  'also': 303,
#  'versatile': 304,
#  'longsleeve': 305,
#  'luxe': 306,
#  'tall': 307,
#  'sheer': 308,
#  'free': 309,
#  'slit': 310,
#  'effortless': 311,
#  'indigo': 312,
#  'snap': 313,
#  'jumpsuit': 314,
#  'great': 315,
#  'wardrobe': 316,
#  'businesscasual': 317,
#  'band': 318,
#  'opening': 319,
#  'delicate': 320,
#  'removable': 321,
#  'composition': 322,
#  'include': 323,
#  'square': 324,
#  'stitch': 325,
#  'jersey': 326,
#  'staple': 327,
#  'patch': 328,
#  'everyday': 329,
#  'return': 330,
#  'prism²': 331,
#  'width': 332,
#  'get': 333,
#  'night': 334,
#  'non': 335,
#  'match': 336,
#  'frame': 337,
#  'around': 338,
#  'romantic': 339,
#  'subtle': 340,
#  'essential': 341,
#  'acrylic': 342,
#  'cozy': 343,
#  'suit': 344,
#  'pre': 345,
#  'brim': 346,
#  'h': 347,
#  'cloth': 348,
#  'nyc': 349,
#  '–': 350,
#  'touch': 351,
#  'grey': 352,
#  'silver': 353,
#  'beach': 354,
#  'complete': 355,
#  'year': 356,
#  'dimension': 357,
#  'blazer': 358,
#  'chiffon': 359,
#  'vacation': 360,
#  'handwoven': 361,
#  'elegant': 362,
#  'subcategorytop': 363,
#  'swimsuit': 364,
#  'update': 365,
#  'plaid': 366,
#  'midlengthathips': 367,
#  'city': 368,
#  'along': 369,
#  'smooth': 370,
#  'face': 371,
#  'swimwear': 372,
#  'right': 373,
#  'coat': 374,
#  'yarn': 375,
#  'smocked': 376,
#  'meet': 377,
#  'plastic': 378,
#  'rubber': 379,
#  'dot': 380,
#  'fly': 381,
#  'sustainable': 382,
#  'see': 383,
#  'throughout': 384,
#  'uppermaterial': 385,
#  'sale': 386,
#  'accessory': 387,
#  'description': 388,
#  'twist': 389,
#  'hoodie': 390,
#  'subcategoryshoe': 391,
#  'beautiful': 392,
#  'le': 393,
#  'yellow': 394,
#  'bodice': 395,
#  'process': 396,
#  'shoewidth': 397,
#  'toestyle': 398,
#  'round': 399,
#  'texture': 400,
#  'tiered': 401,
#  '®': 402,
#  'trouser': 403,
#  'help': 404,
#  'cardigan': 405,
#  'studio': 406,
#  'fringe': 407,
#  'timeless': 408,
#  'archive': 409,
#  'nightout': 410,
#  'leave': 411,
#  'closureshoe': 412,
#  'metal': 413,
#  'u': 414,
#  'synthetic': 415,
#  'fine': 416,
#  'across': 417,
#  'canvas': 418,
#  'legging': 419,
#  'statement': 420,
#  'ultra': 421,
#  'fiber': 422,
#  'poly': 423,
#  'store': 424,
#  'xl': 425,
#  'travel': 426,
#  'three': 427,
#  'roll': 428,
#  'paint': 429,
#  'due': 430,
#  'instruction': 431,
#  'avoid': 432,
#  'bold': 433,
#  'weather': 434,
#  'scarf': 435,
#  'hardware': 436,
#  'printed': 437,
#  'little': 438,
#  'tote': 439,
#  'la': 440,
#  'twill': 441,
#  'uk': 442,
#  'hit': 443,
#  'slight': 444,
#  'crossbody': 445,
#  'place': 446,
#  'striped': 447,
#  'placket': 448,
#  'edgy': 449,
#  'tailor': 450,
#  'raw': 451,
#  'luxurious': 452,
#  'accent': 453,
#  'cap': 454,
#  'protection': 455,
#  'perfectly': 456,
#  'flare': 457,
#  'remove': 458,
#  'crown': 459,
#  'custom': 460,
#  'maxi': 461,
#  'allow': 462,
#  'm': 463,
#  'air': 464,
#  'foot': 465,
#  'impact': 466,
#  'sleek': 467,
#  'life': 468,
#  'nature': 469,
#  'loop': 470,
#  'swim': 471,
#  'spec': 472,
#  'crepe': 473,
#  'functional': 474,
#  'normal': 475,
#  'accra': 476,
#  'first': 477,
#  'knee': 478,
#  'mix': 479,
#  'want': 480,
#  'unlined': 481,
#  'dark': 482,
#  'spain': 483,
#  'buckle': 484,
#  'panel': 485,
#  'graphic': 486,
#  'bodysuit': 487,
#  'nappa': 488,
#  'minimal': 489,
#  'seamless': 490,
#  'performance': 491,
#  'subcategorybottom': 492,
#  'half': 493,
#  'spring': 494,
#  'alpaca': 495,
#  'rich': 496,
#  'simple': 497,
#  'final': 498,
#  'eco': 499,
#  'detailing': 500,
#  'satin': 501,
#  'french': 502,
#  'produce': 503,
#  'merino': 504,
#  'special': 505,
#  'breathable': 506,
#  'mesh': 507,
#  'fashion': 508,
#  'eye': 509,
#  'split': 510,
#  'pleated': 511,
#  'shop': 512,
#  'india': 513,
#  'traditional': 514,
#  'drape': 515,
#  'sit': 516,
#  'vegan': 517,
#  'stretchy': 518,
#  'bring': 519,
#  'circumference': 520,
#  'boxy': 521,
#  'xs': 522,
#  'embroider': 523,
#  'acetate': 524,
#  'put': 525,
#  'street': 526,
#  'insole': 527,
#  'lay': 528,
#  'embroidery': 529,
#  'quality': 530,
#  'slide': 531,
#  'resistant': 532,
#  'playful': 533,
#  'de': 534,
#  'classpantsandleggings': 535,
#  'coverage': 536,
#  'b': 537,
#  'trend': 538,
#  'embossed': 539,
#  'unisex': 540,
#  'com': 541,
#  'art': 542,
#  'skin': 543,
#  'hook': 544,
#  'handbags': 545,
#  'mean': 546,
#  'lead': 547,
#  'ivory': 548,
#  'sophisticated': 549,
#  'velvet': 550,
#  'hide': 551,
#  'faux': 552,
#  'scoop': 553,
#  'leopard': 554,
#  'kind': 555,
#  'inside': 556,
#  'textile': 557,
#  'vegetable': 558,
#  'tuck': 559,
#  'drawstre': 560,
#  'gently': 561,
#  'drawstring': 562,
#  'ideal': 563,
#  'androgynous': 564,
#  'card': 565,
#  'semifitted': 566,
#  'tencel': 567,
#  'gentle': 568,
#  'terry': 569,
#  'styling': 570,
#  'polished': 571,
#  'team': 572,
#  'everything': 573,
#  'carry': 574,
#  'ensure': 575,
#  'form': 576,
#  'gather': 577,
#  'vibrant': 578,
#  'portugal': 579,
#  'friendly': 580,
#  'flap': 581,
#  'colorway': 582,
#  'heelheight': 583,
#  'fresh': 584,
#  'effect': 585,
#  'exclusive': 586,
#  'construction': 587,
#  'japanese': 588,
#  'gram': 589,
#  'panama': 590,
#  'kenya': 591,
#  'platform': 592,
#  'retro': 593,
#  'hold': 594,
#  'ultimate': 595,
#  'soap': 596,
#  'animal': 597,
#  'sure': 598,
#  'whole': 599,
#  'pima': 600,
#  'tunic': 601,
#  'brown': 602,
#  'ship': 603,
#  'enough': 604,
#  'source': 605,
#  'local': 606,
#  'point': 607,
#  'orange': 608,
#  'structured': 609,
#  'jacquard': 610,
#  'hw': 611,
#  'woven': 612,
#  'calfskin': 613,
#  'basket': 614,
#  'oz': 615,
#  'northern': 616,
#  'fun': 617,
#  'turtleneck': 618,
#  'collared': 619,
#  'clutch': 620,
#  'mule': 621,
#  'magnetic': 622,
#  'lemlem': 623,
#  'production': 624,
#  'ready': 625,
#  'pantsleggings': 626,
#  'never': 627,
#  'toeexposure': 628,
#  'together': 629,
#  'rinse': 630,
#  'baby': 631,
#  'find': 632,
#  'additional': 633,
#  'part': 634,
#  'hood': 635,
#  'technique': 636,
#  'ruffled': 637,
#  'elevated': 638,
#  'tip': 639,
#  'sweat': 640,
#  'virgin': 641,
#  'elevate': 642,
#  'credit': 643,
#  "'ll": 644,
#  'stylish': 645,
#  'tight': 646,
#  'tonal': 647,
#  'heelshape': 648,
#  'washable': 649,
#  'suitable': 650,
#  'waste': 651,
#  'sun': 652,
#  'house': 653,
#  'n': 654,
#  'ever': 655,
#  'earring': 656,
#  'modal': 657,
#  'pop': 658,
#  'approx': 659,
#  'handbag': 660,
#  'pack': 661,
#  'contact': 662,
#  'oil': 663,
#  'thread': 664,
#  'home': 665,
#  'thin': 666,
#  'surface': 667,
#  'poplin': 668,
#  'cycle': 669,
#  'asymmetrical': 670,
#  'live': 671,
#  'outfit': 672,
#  'know': 673,
#  'cup': 674,
#  'version': 675,
#  'calf': 676,
#  'cottonblend': 677,
#  'designer': 678,
#  't': 679,
#  'pleat': 680,
#  'softness': 681,
#  'stain': 682,
#  'prism': 683,
#  'america': 684,
#  'vibe': 685,
#  'easily': 686,
#  'brand': 687,
#  'offset': 688,
#  'buttonedfront': 689,
#  'cream': 690,
#  'brush': 691,
#  'durable': 692,
#  'boho': 693,
#  'grow': 694,
#  'try': 695,
#  'move': 696,
#  'without': 697,
#  'heat': 698,
#  'eyelet': 699,
#  'none': 700,
#  'end': 701,
#  'straightregular': 702,
#  'limited': 703,
#  'evening': 704,
#  'purecotton': 705,
#  'last': 706,
#  'name': 707,
#  'uv': 708,
#  'ease': 709,
#  'chunky': 710,
#  'http': 711,
#  'sportswear': 712,
#  'tapered': 713,
#  'throw': 714,
#  'a': 715,
#  'tanned': 716,
#  'padded': 717,
#  'slimmy': 718,
#  'lense': 719,
#  'caftan': 720,
#  'heavy': 721,
#  'tassel': 722,
#  'flower': 723,
#  'cinch': 724,
#  'closurepantsandleggings': 725,
#  'suggest': 726,
#  'buttondown': 727,
#  'fastening': 728,
#  'girl': 729,
#  'beige': 730,
#  'cross': 731,
#  'bow': 732,
#  'lounge': 733,
#  'waisted': 734,
#  'must': 735,
#  'chain': 736,
#  'boy': 737,
#  'california': 738,
#  'textured': 739,
#  'combine': 740,
#  'voile': 741,
#  'key': 742,
#  'result': 743,
#  'addition': 744,
#  'layered': 745,
#  'pouch': 746,
#  "n't": 747,
#  'classhandbags': 748,
#  'prescription': 749,
#  'hot': 750,
#  'lengthpantsandleggings': 751,
#  'edition': 752,
#  'kick': 753,
#  'plant': 754,
#  'flowy': 755,
#  'hue': 756,
#  'direct': 757,
#  'wicke': 758,
#  'flutter': 759,
#  'max': 760,
#  'damage': 761,
#  'footbed': 762,
#  'surf': 763,
#  'wax': 764,
#  'test': 765,
#  'default': 766,
#  'pearl': 767,
#  'even': 768,
#  'legstyle': 769,
#  'structure': 770,
#  'chufy': 771,
#  'shell': 772,
#  'closuretop': 773,
#  'standard': 774,
#  'fitting': 775,
#  'premium': 776,
#  'movement': 777,
#  'closedtoe': 778,
#  'handcraft': 779,
#  'rose': 780,
#  'wood': 781,
#  'hemline': 782,
#  'breezy': 783,
#  'polyurethane': 784,
#  'glam': 785,
#  'iconic': 786,
#  'quick': 787,
#  'filter': 788,
#  'eligible': 789,
#  'man': 790,
#  'become': 791,
#  'relax': 792,
#  'crisp': 793,
#  'wallet': 794,
#  'world': 795,
#  'exchange': 796,
#  'embellishment': 797,
#  'head': 798,
#  'flatter': 799,
#  'fold': 800,
#  'anywhere': 801,
#  'sew': 802,
#  'separately': 803,
#  'beautifully': 804,
#  'bralette': 805,
#  'gorgeous': 806,
#  'cami': 807,
#  'yoke': 808,
#  'tan': 809,
#  'option': 810,
#  'comfy': 811,
#  'effortlessly': 812,
#  'highover9': 813,
#  'core': 814,
#  'kid': 815,
#  'cause': 816,
#  'closurehandbag': 817,
#  'polish': 818,
#  'technology': 819,
#  'fittedtailored': 820,
#  'forward': 821,
#  'gray': 822,
#  'rough': 823,
#  'semi': 824,
#  'sweet': 825,
#  'condition': 826,
#  'conceal': 827,
#  'figure': 828,
#  'bright': 829,
#  'clothing': 830,
#  'men': 831,
#  'micro': 832,
#  'c': 833,
#  'change': 834,
#  'collaboration': 835,
#  'close': 836,
#  'construct': 837,
#  'draw': 838,
#  'roundtoe': 839,
#  'big': 840,
#  'female': 841,
#  'spin': 842,
#  'lens': 843,
#  'certify': 844,
#  'workout': 845,
#  'keyhole': 846,
#  'hair': 847,
#  'contour': 848,
#  'deadstock': 849,
#  'waiste': 850,
#  'thong': 851,
#  'blouson': 852,
#  'ruched': 853,
#  'turkey': 854,
#  'raglan': 855,
#  'sunglass': 856,
#  'underwear': 857,
#  'tab': 858,
#  'strong': 859,
#  'colorful': 860,
#  'thigh': 861,
#  'lambskin': 862,
#  'lurex': 863,
#  'coordinate': 864,
#  'python': 865,
#  'safe': 866,
#  'france': 867,
#  'patent': 868,
#  'fade': 869,
#  'tone': 870,
#  'refined': 871,
#  'always': 872,
#  'original': 873,
#  'subcategoryaccessory': 874,
#  'chambray': 875,
#  'pump': 876,
#  'ring': 877,
#  'classdress': 878,
#  'brass': 879,
#  'follow': 880,
#  'volume': 881,
#  'welt': 882,
#  'moisture': 883,
#  '·': 884,
#  'image': 885,
#  'millinery': 886,
#  'potential': 887,
#  'paxtyn': 888,
#  'classsandals': 889,
#  'mother': 890,
#  'shortsleeve': 891,
#  'bond': 892,
#  'solid': 893,
#  'gift': 894,
#  'panty': 895,
#  'scratch': 896,
#  'info': 897,
#  'pencil': 898,
#  'ancient': 899,
#  'ocean': 900,
#  'fleece': 901,
#  'mock': 902,
#  'turn': 903,
#  'jewelry': 904,
#  'recycle': 905,
#  'next': 906,
#  'extended': 907,
#  'label': 908,
#  'coast': 909,
#  'build': 910,
#  'sunlight': 911,
#  'miller': 912,
#  'neoprene': 913,
#  'bit': 914,
#  'slingback': 915,
#  'foam': 916,
#  'sand': 917,
#  'blanket': 918,
#  'crochet': 919,
#  'basic': 920,
#  'pajama': 921,
#  'stitching': 922,
#  'choose': 923,
#  'voluminous': 924,
#  'bucket': 925,
#  'd': 926,
#  'check': 927,
#  'washing': 928,
#  'airy': 929,
#  'athleisure': 930,
#  'xxs': 931,
#  'resist': 932,
#  'locally': 933,
#  'spaghetti': 934,
#  'thoughtful': 935,
#  'define': 936,
#  'colour': 937,
#  'simon': 938,
#  'materialpurse': 939,
#  'polo': 940,
#  'preserve': 941,
#  'wave': 942,
#  'cleanable': 943,
#  'stay': 944,
#  'vneck': 945,
#  'stand': 946,
#  'brazil': 947,
#  'state': 948,
#  'gauze': 949,
#  'packable': 950,
#  'variation': 951,
#  "'ve": 952,
#  'wet': 953,
#  'onepiece': 954,
#  'abstract': 955,
#  'room': 956,
#  'motif': 957,
#  'faherty': 958,
#  'secure': 959,
#  'subcategoryonepiece': 960,
#  'lengthonepiece': 961,
#  'exclusively': 962,
#  'develop': 963,
#  'taper': 964,
#  'heather': 965,
#  'lamb': 966,
#  'elasticated': 967,
#  'silky': 968,
#  'econyl': 969,
#  'pad': 970,
#  'georgette': 971,
#  'msrp': 972,
#  'prefer': 973,
#  'transition': 974,
#  'curve': 975,
#  'warmth': 976,
#  'factory': 977,
#  'camel': 978,
#  'wring': 979,
#  'lie': 980,
#  'screw': 981,
#  'medical': 982,
#  'wrinkle': 983,
#  'sweatpant': 984,
#  'opentoe': 985,
#  'croc': 986,
#  'heart': 987,
#  'kimono': 988,
#  'peruvian': 989,
#  'thick': 990,
#  'sock': 991,
#  'curved': 992,
#  'balance': 993,
#  'post': 994,
#  'oca': 995,
#  'compartment': 996,
#  'neutral': 997,
#  'west': 998,
#  'fedora': 999,
#  'star': 1000,
#  ...}

# %%
# create a weight matrix for words in training docs
embedding_matrix = zeros((VOCAB_SIZE, 100))
for word, i in tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: # check that it is an actual word that we have embeddings for
        embedding_matrix[i] = embedding_vector

# %%
len(padded_docs)
# Out:
# 61355

# %%
from random import randint
from numpy import array, argmax, asarray, zeros
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers.recurrent import SimpleRNN
from keras.layers import Flatten, Masking
# define model
model = Sequential()
model.add(Embedding(embedding_matrix.shape[0], 
                    100, 
                    weights=[embedding_matrix], 
                    input_length=MAX_SEQUENCE_LENGTH, trainable=False))
model.add(Masking(mask_value=0.0)) # masking layer, masks any words that don't have an embedding as 0s.
model.add(SimpleRNN(units=64, input_shape=(1, MAX_SEQUENCE_LENGTH)))
model.add(Dense(64))
model.add(Dense(51, activation='softmax'))

# %%
from keras.utils.vis_utils import plot_model

# Compile the model
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# summarize the model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 300, 100)          3327300
# _________________________________________________________________
# masking_2 (Masking)          (None, 300, 100)          0
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 64)                10560
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 51)                3315
# =================================================================
# Total params: 3,345,335
# Trainable params: 18,035
# Non-trainable params: 3,327,300
# _________________________________________________________________
# None
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
model.fit(X_train, y_train, validation_split = 0.2, epochs=20, verbose=1)
# Out:
# Epoch 1/20
#